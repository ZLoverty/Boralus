# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
folder = r"C:\Users\zl948\Downloads"
a = loadmat(os.path.join(folder, "T.mat"))["concen_t"]
b = loadmat(os.path.join(folder, "FTLE.mat"))["FTLE_val"]

# %%
# b[b < 1] = np.nan

# %%
# Plot the images with transparency
plt.figure(dpi=300)
plt.imshow(a, cmap='Oranges', interpolation="spline16")  # First image with 50% transparency
plt.imshow(b, cmap='winter', alpha=.5, interpolation="spline16")  # Second image with 50% transparency
plt.axis('off')  # Turn off the axis
plt.show()
